# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [raw]
# #Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
df = pd.read_csv('Never Married.csv')
df.head()
# Out:
#    index Gender Age Range  Year  Never Married
# 0      0  Women     25-29  2006          0.456
# 1      1  Women     25-29  2016          0.597
# 2      2    Men     25-29  2006          0.579
# 3      3    Men     25-29  2016          0.709
# 4      4  Women     30-34  2006          0.262

# %%
# Look at all the rows of the dataframe
display(df)
# Out:
#     index Gender Age Range  Year  Never Married
# 0       0  Women     25-29  2006          0.456
# 1       1  Women     25-29  2016          0.597
# 2       2    Men     25-29  2006          0.579
# 3       3    Men     25-29  2016          0.709
# 4       4  Women     30-34  2006          0.262
# 5       5  Women     30-34  2016          0.361
# 6       6    Men     30-34  2006          0.348
# 7       7    Men     30-34  2016          0.458
# 8       8  Women     35-44  2006          0.164
# 9       9  Women     35-44  2016          0.212
# 10     10    Men     35-44  2006          0.216
# 11     11    Men     35-44  2016          0.265
# 12     12  Women     45-54  2006          0.106
# 13     13  Women     45-54  2016          0.135
# 14     14    Men     45-54  2006          0.136
# 15     15    Men     45-54  2016          0.172
# 16     16  Women       55+  2006          0.055
# 17     17  Women       55+  2016          0.074
# 18     18    Men       55+  2006          0.061
# ...

# %%
# Get a concise summary of the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          20 non-null     int64
#  1   Gender         20 non-null     object
#  2   Age Range      20 non-null     object
#  3   Year           20 non-null     int64
#  4   Never Married  20 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 928.0+ bytes
# None

# %%
df.drop('Year', axis = 1, inplace = True)
df.drop('Year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_616\3864646475.py in <module>
# ----> 1 df.drop('Year', axis = 1, inplace = True)
#       2 df.drop('Year')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# Check the column names in your DataFrame
print(df.columns)
# Out:
# Index(['index', 'Gender', 'Age Range', 'Never Married'], dtype='object')

# %%
# Get a concise summary of the dataframe
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          20 non-null     int64
#  1   Gender         20 non-null     object
#  2   Age Range      20 non-null     object
#  3   Never Married  20 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 768.0+ bytes
# None

# %%
df = df.drop(16)

# %%
display(df)
# Out:
#     index Gender Age Range  Never Married
# 0       0  Women     25-29          0.456
# 1       1  Women     25-29          0.597
# 2       2    Men     25-29          0.579
# 3       3    Men     25-29          0.709
# 4       4  Women     30-34          0.262
# 5       5  Women     30-34          0.361
# 6       6    Men     30-34          0.348
# 7       7    Men     30-34          0.458
# 8       8  Women     35-44          0.164
# 9       9  Women     35-44          0.212
# 10     10    Men     35-44          0.216
# 11     11    Men     35-44          0.265
# 12     12  Women     45-54          0.106
# 13     13  Women     45-54          0.135
# 14     14    Men     45-54          0.136
# 15     15    Men     45-54          0.172
# 17     17  Women       55+          0.074
# 18     18    Men       55+          0.061
# 19     19    Men       55+          0.088

# %%
# Sample data
ages = [25, 30, 40, 45, 50, 55, 60]

# Create a bar chart
plt.bar(range(len(ages)), ages)

# Adding labels and title
plt.xlabel("Age Group")
plt.ylabel("Never Married ")
plt.title("Age Distribution in the Population")

# Customize x-axis labels if needed
plt.xticks(range(len(ages)), ["Group 1", "Group 2", "Group 3", "Group 4", "Group 5", "Group 6", "Group 7"])

# Display the chart
plt.show()
